# %%
# Limpeza e tratamento de dados
import pandas as pd # importando a biblioteca pandas para tratamento de df
import seaborn as srn # importando a biblioteca seaborn para graficos 
import statistics as sts # importando biblioteca statistcs para estatisticas

# %%
# importando dados
dataset = pd.read_csv("Churn.csv", sep=";" ) # comando "read" para ler o arquivo CSV e chamamnos a função "sep" para separar por ";"
dataset.head # visualiza cabeçalho do dataframe
# Out:
# <bound method NDFrame.head of        X0   X1  X2         X3  X4  X4.1        X6  X7  X8  X9         X10  X11
# 0       1  619  RS   Feminino  42     2         0   1   1   1  10134888.0    1
# 1       2  608  SC   Feminino  41     1   8380786   1   0   1  11254258.0    0
# 2       3  502  RS   Feminino  42     8   1596608   3   1   0  11393157.0    1
# 3       4  699  RS   Feminino  39     1         0   2   0   0   9382663.0    0
# 4       5  850  SC   Feminino  43     2  12551082   1   1   1    790841.0    0
# ..    ...  ...  ..        ...  ..   ...       ...  ..  ..  ..         ...  ...
# 994   996  838  SC  Masculino  43     9  12310588   2   1   0  14576583.0    0
# 995   997  610  SC  Masculino  29     9         0   3   0   1   8391224.0    0
# 996   998  811  SC  Masculino  44     3         0   2   0   1   7843973.0    0
# 997   999  587  SC  Masculino  62     7  12128627   1   0   1    677692.0    0
# 998  1000  811  PR   Feminino  28     4  16773882   2   1   1    990342.0    0
#
# [999 rows x 12 columns]>

# %%
# tamanho do dataframe
dataset.shape
# Out:
# (999, 12)

# %%
# dar nome as colunas
dataset.columns = ["id", "Score", "Estado", "Genero", "Idade", "Patrimonio", "Saldo",
                   "Produtos", "TemCartCredito", "Ativo", "Salario", "saiu"]

# %%
dataset.head() # vizualiza o cabeçalho
# Out:
#    id  Score Estado    Genero  Idade  Patrimonio     Saldo  Produtos  \
# 0   1    619     RS  Feminino     42           2         0         1
# 1   2    608     SC  Feminino     41           1   8380786         1
# 2   3    502     RS  Feminino     42           8   1596608         3
# 3   4    699     RS  Feminino     39           1         0         2
# 4   5    850     SC  Feminino     43           2  12551082         1
#
#    TemCartCredito  Ativo     Salario  saiu
# 0               1      1  10134888.0     1
# 1               0      1  11254258.0     0
# 2               1      0  11393157.0     1
# 3               0      0   9382663.0     0
# 4               1      1    790841.0     0

# %%
# explorar dados categoricos
# estado
agrupar = dataset.groupby(['Estado']).size() # agrupando os dados pela coluna "estado". Size conta os numeros de linhas(ocorrencias)em cada grupo
agrupar
# Out:
# Estado
# PR    257
# RP      1
# RS    478
# SC    258
# SP      4
# TD      1
# dtype: int64

# %%
agrupar.plot.bar(color = 'green') # .plot.bar() PEde para p pandas criar um grafico de barras a partir dessa series
# Out:
# <Axes: xlabel='Estado'>

# %%
# categoria por genero
agrupado = dataset.groupby(['Genero']).size()
agrupado
# Out:
# Genero
# F              2
# Fem            1
# Feminino     461
# M              6
# Masculino    521
# dtype: int64

# %%
agrupado.plot.bar(color = 'green')
# Out:
# <Axes: xlabel='Genero'>

# %%
# explorar colunas numericas
#Score
dataset['Score'].describe()
# Out:
# count    999.000000
# mean     648.621622
# std       98.264219
# min      376.000000
# 25%      580.000000
# 50%      653.000000
# 75%      721.000000
# max      850.000000
# Name: Score, dtype: float64

# %%
srn.boxplot(dataset['Score']).set_title('Score')
# Out:
# Text(0.5, 1.0, 'Score')

# %%
srn.distplot(dataset['Score']).set_title('Score')
# Out:
# C:\Users\maxni\AppData\Local\Temp\ipykernel_7584\4068248596.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(dataset['Score']).set_title('Score')
# Text(0.5, 1.0, 'Score')

# %%
# idade
dataset['Idade'].describe()
# Out:
# count    999.000000
# mean      38.902903
# std       11.401912
# min      -20.000000
# 25%       32.000000
# 50%       37.000000
# 75%       44.000000
# max      140.000000
# Name: Idade, dtype: float64

# %%
srn.boxplot(dataset['Idade']).set_title('Idade')
# Out:
# Text(0.5, 1.0, 'Idade')

# %%
srn.distplot(dataset['Idade']).set_title('Idade')
# Out:
# C:\Users\maxni\AppData\Local\Temp\ipykernel_7584\1712185710.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(dataset['Idade']).set_title('Idade')
# Text(0.5, 1.0, 'Idade')

# %%
# saldo data
dataset['Saldo'].describe()
# Out:
# count    9.990000e+02
# mean     7.164928e+06
# std      6.311840e+06
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      8.958835e+06
# 75%      1.258684e+07
# max      2.117743e+07
# Name: Saldo, dtype: float64

# %%
srn.boxplot(dataset['Saldo']).set_title('Saldo')
# Out:
# Text(0.5, 1.0, 'Saldo')

# %%
sbn.distplot(dataset['Saldo']).set_title('Saldo')
# Out:
# C:\Users\maxni\AppData\Local\Temp\ipykernel_7584\823464510.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbn.distplot(dataset['Saldo']).set_title('Saldo')
# Text(0.5, 1.0, 'Saldo')

# %%
#Salario
dataset['Salario'].describe()
# Out:
# count    9.920000e+02
# mean     3.528762e+07
# std      5.305800e+08
# min      9.677000e+03
# 25%      3.029011e+06
# 50%      8.703250e+06
# 75%      1.405213e+07
# max      1.193469e+10
# Name: Salario, dtype: float64

# %%
srn.boxplot(dataset['Salario']).set_title('Salario')
# Out:
# Text(0.5, 1.0, 'Salario')
